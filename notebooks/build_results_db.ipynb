# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 400)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import joblib
from sklearn.tree import DecisionTreeRegressor

# %%
specs = pd.read_csv('../data/specs_clean.csv')
specs = specs[specs['original_price']<3000] # resale model only valid in this range
len(specs)
# Out:
# 311

# %%
resale_price_model = joblib.load('../data/resale_price_model.pkl')
prep_pipeline = joblib.load('../data/prep_pipeline.pkl')

# %% [markdown]
# ### Predict and append resale price for each lens

# %%
specs['brand'].unique()
# Out:
# array(['leica', 'canon', 'sony', 'samsung', 'fujifilm', 'nikon', 'tamron',
#        'olympus', 'venus', 'panasonic', 'tokina', 'pentax', 'samyang',
#        'voigtlander', 'sigma', 'nikkor', 'rokinon'], dtype=object)

# %%
# replace all but sony, fujifilm, panasonic and nikon
specs.replace(['leica', 'canon', 'samsung', 'tamron','olympus', 'venus', 'tokina', 'pentax', 'samyang','voigtlander', 'sigma', 'nikkor', 'rokinon'], 'other', inplace=True)

# %%
x_all = specs[['original_price', 'flen_max', 'flen_min', 'f_min','brand', 'announce_date']]
x_all_prepd = prep_pipeline.transform(x_all)
specs['resale_price'] = resale_price_model.predict(x_all_prepd)

# %%
import matplotlib.pyplot as plt

plt.hist(specs['resale_price']/specs['original_price'], bins=20);

# %% [markdown]
# ### Append usage scores

# %%
usage_opts = {'wildlife','landscape','portraits','low_light'}
for usage in usage_opts:
    usage_stats = pd.read_csv('../data/usage_'+usage+'.csv')
    df_ = pd.DataFrame(usage_stats['lens_id'].value_counts().reset_index()) 
    df_.columns = ['lens_id', usage+'_score']
    specs = pd.merge(specs, df_, on='lens_id', how='left')
    specs[usage+'_score'] = specs[usage+'_score'].fillna(0)

# %%
specs.head()
# Out:
#                     lens_id     brand  original_price  announce_date  format  \
# 0    leica_t_55-135_3p5-4p5     other        2095.000           2014    1.33
# 1  canon_70-200_4_is_ii_usm     other        1299.000           2018    2.00
# 2            sony_fe_50_1p8      sony         247.975           2016    2.00
# 3            samsung_10_3p5     other         552.820           2013    1.33
# 4     fujifilm_xc_50-230_ii  fujifilm         399.000           2015    1.33
#
#    flen_min  flen_max  image_stabilization  f_min  elements  ...  \
# 0      55.0     135.0                False    3.5        12  ...
# 1      70.0     200.0                 True    4.0        20  ...
# 2      50.0      -1.0                False    1.8         6  ...
# 3      10.0      -1.0                False    3.5         7  ...
# 4      50.0     230.0                 True    4.5        13  ...
#
#    maximum_magnification  autofocus  weight  sealing  \
# 0                  -1.00       True     500    False
# 1                   0.27       True     780     True
# 2                   0.14       True     186    False
# 3                   0.22       True      71    False
# 4                   0.20       True      -1    False
#
#                                                                                                                   image_href  \
# 0    https://4.img-dpreview.com/files/p/TS375x375~products/leica_t_55-135_3p5-4p5/shots/b1ff88457a1f4ee6b289e920d8943673.png
# 1  https://3.img-dpreview.com/files/p/TS375x375~products/canon_70-200_4_is_ii_usm/shots/7ecb678ec914424486ca2ac9d326497a.png
# 2            https://3.img-dpreview.com/files/p/TS375x375~products/sony_fe_50_1p8/shots/414d9391e4164c2eb1eeb460f7b2f741.png
# 3            https://4.img-dpreview.com/files/p/TS375x375~products/samsung_10_3p5/shots/fd37e35f19714e7c88a8b3dd06753c91.png
# 4     https://1.img-dpreview.com/files/p/TS375x375~products/fujifilm_xc_50-230_ii/shots/eeb3eebf26664d0d8e0bb676053fba52.png
#
#    resale_price wildlife_score  portraits_score  low_light_score  \
# 0    858.333333            0.0              0.0              0.0
# 1    388.571429            4.0              3.0              1.0
# 2    153.333333            0.0              8.0              8.0
# 3    337.500000            0.0              0.0              0.0
# 4    170.000000            0.0              0.0              4.0
#
#    landscape_score
# 0              0.0
# 1              2.0
# 2              2.0
# 3              0.0
# 4              3.0
#
# [5 rows x 22 columns]

# %%
len(specs)
# Out:
# 311

# %% [markdown]
# ### Restore brand labels

# %%
specs['brand'] = specs['lens_id'].apply(lambda x: x.split('_')[0])

# %%
specs.head()
# Out:
#                     lens_id     brand  original_price  announce_date  format  \
# 0    leica_t_55-135_3p5-4p5     leica        2095.000           2014    1.33
# 1  canon_70-200_4_is_ii_usm     canon        1299.000           2018    2.00
# 2            sony_fe_50_1p8      sony         247.975           2016    2.00
# 3            samsung_10_3p5   samsung         552.820           2013    1.33
# 4     fujifilm_xc_50-230_ii  fujifilm         399.000           2015    1.33
#
#    flen_min  flen_max  image_stabilization  f_min  elements  ...  \
# 0      55.0     135.0                False    3.5        12  ...
# 1      70.0     200.0                 True    4.0        20  ...
# 2      50.0      -1.0                False    1.8         6  ...
# 3      10.0      -1.0                False    3.5         7  ...
# 4      50.0     230.0                 True    4.5        13  ...
#
#    maximum_magnification  autofocus  weight  sealing  \
# 0                  -1.00       True     500    False
# 1                   0.27       True     780     True
# 2                   0.14       True     186    False
# 3                   0.22       True      71    False
# 4                   0.20       True      -1    False
#
#                                                                                                                   image_href  \
# 0    https://4.img-dpreview.com/files/p/TS375x375~products/leica_t_55-135_3p5-4p5/shots/b1ff88457a1f4ee6b289e920d8943673.png
# 1  https://3.img-dpreview.com/files/p/TS375x375~products/canon_70-200_4_is_ii_usm/shots/7ecb678ec914424486ca2ac9d326497a.png
# 2            https://3.img-dpreview.com/files/p/TS375x375~products/sony_fe_50_1p8/shots/414d9391e4164c2eb1eeb460f7b2f741.png
# 3            https://4.img-dpreview.com/files/p/TS375x375~products/samsung_10_3p5/shots/fd37e35f19714e7c88a8b3dd06753c91.png
# 4     https://1.img-dpreview.com/files/p/TS375x375~products/fujifilm_xc_50-230_ii/shots/eeb3eebf26664d0d8e0bb676053fba52.png
#
#    resale_price wildlife_score  portraits_score  low_light_score  \
# 0    858.333333            0.0              0.0              0.0
# 1    388.571429            4.0              3.0              1.0
# 2    153.333333            0.0              8.0              8.0
# 3    337.500000            0.0              0.0              0.0
# 4    170.000000            0.0              0.0              4.0
#
#    landscape_score
# 0              0.0
# 1              2.0
# 2              2.0
# 3              0.0
# 4              3.0
#
# [5 rows x 22 columns]

# %%
specs.describe()
# Out:
#        original_price  announce_date      format    flen_min    flen_max  \
# count      311.000000     311.000000  311.000000  311.000000  311.000000
# mean       876.319019    2014.520900    1.589389   42.390675   74.099678
# std        658.003478       2.734259    0.405383   43.904838  118.923883
# min         98.720000    2010.000000    1.000000    7.500000   -1.000000
# 25%        399.000000    2012.000000    1.330000   16.000000   -1.000000
# 50%        629.000000    2014.000000    1.330000   25.000000   16.000000
# 75%       1081.950000    2017.000000    2.000000   50.000000  105.000000
# max       2999.000000    2020.000000    2.000000  300.000000  600.000000
#
#             f_min    elements      groups  minimum_focus  \
# count  311.000000  311.000000  311.000000     311.000000
# mean     2.940193   13.003215    9.845659       0.467878
# std      1.185079    4.845016    3.604026       0.409666
# min      1.000000   -1.000000   -1.000000      -1.000000
# 25%      2.000000   10.000000    8.000000       0.240000
# 50%      2.800000   13.000000   10.000000       0.300000
# 75%      3.500000   16.000000   12.000000       0.500000
# max     12.000000   32.000000   24.000000       2.700000
#
#        maximum_magnification       weight  resale_price  wildlife_score  \
# count             311.000000   311.000000    311.000000      311.000000
# mean                0.105479   525.041801    499.883208        3.697749
# std                 0.602226   429.664552    415.647763       21.405274
# min                -1.000000    -1.000000     50.000000        0.000000
# 25%                 0.120000   209.000000    230.592500        0.000000
# 50%                 0.200000   453.000000    375.000000        0.000000
# 75%                 0.260000   700.000000    651.361789        1.000000
# max                 5.000000  2860.000000   2474.250000      288.000000
#
#        portraits_score  low_light_score  landscape_score
# count       311.000000       311.000000       311.000000
# mean          2.382637         2.266881         2.009646
# std           7.463776         4.233068         3.766992
# min           0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000
# 50%           0.000000         0.000000         0.000000
# 75%           2.000000         3.000000         2.000000
# max          93.000000        36.000000        30.000000

# %% [markdown]
# ### Create final DB

# %%
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

dbname, tabname, username = 'results_db', 'results', 'ana'
engine = create_engine(f'postgresql://{username}:nonsense@localhost/{dbname}')
print(f'Created engine: {engine.url}')
if database_exists(engine.url):
  print(f'Database {dbname} found.')
else:
  print(f'Database {dbname} not found. Creating database...',)
  create_database(engine.url)
  print('Done.')

specs.to_sql(tabname, engine, if_exists='replace')
print(f'Wrote {tabname} table to {dbname}.')
# Out:
# Created engine: postgresql://ana:nonsense@localhost/results_db
# Database results_db found.
# Wrote results table to results_db.
